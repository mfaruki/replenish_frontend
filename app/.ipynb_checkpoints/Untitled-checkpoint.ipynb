# %%
import pandas as pd
import numpy as np
import os
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import string

# %%
path = os.path.join(os.path.dirname(os.getcwd()),'raw_data')
df = pd.read_csv(os.path.join(path,'bbc_final_df.csv'))

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                             recipe_title      dietary stars  \
# 0                                   Easy creamed spinach   vegetarian   4.6
# 1                                   Easy creamed spinach  gluten-free   4.6
# 2                             Simple coconut & bean soup   vegetarian   4.8
# 3                               Free-form Florentine pie   vegetarian   3.8
# 4                                       Fresh herb sauce   vegetarian   4.0
# ...                                                  ...          ...   ...
# 10878                                       Easy noodles            n   3.8
# 10879  Rice noodle & turkey salad with lime-chilli dr...            n   4.3
# 10880                     Cevapcici with red pepper rice            n     n
# 10881                Pork & cabbage with bread dumplings            n     n
# 10882                          Pork & sauerkraut goulash            n     n
#
#       prep_times cooking_times review_count difficulty_level      servings  \
# 0              2             6          5.0             Easy      Serves 2
# 1              2             6          5.0             Easy      Serves 2
# 2             10            20         22.0             Easy      Serves 4
# 3             10            35         14.0             Easy      Serves 4
# 4              5             5          1.0             Easy      Serves 8
# ...          ...           ...          ...              ...           ...
# 10878         20             n         23.0             Easy      Serves 4
# 10879         20            10         10.0             Easy      Serves 4
# 10880         25            30            n             Easy      Serves 4
# 10881         40  3 hrs and 30            n             Easy  Serves 4 - 6
# 10882         10   1 hr and 25            n             Easy  Serves 4 - 6
#
#                                              description  \
# 0      Double cream, Parmesan cheese and a pinch of n...
# 1      Double cream, Parmesan cheese and a pinch of n...
# 2      This vegetarian meal in a bowl shows how somet...
# 3      You're just six ingredients away from an impre...
# 4      This fresh green purée is a light alternative ...
# ...                                                  ...
# 10878  This simple version of a Malaysian classic is ...
# 10879  Lean turkey mince is low in fat - serve with n...
# 10880  These flavourful spiced beef meatballs with to...
# 10881  Try this simple dish of succulent slow-cooked ...
# 10882  Szegedin goulash is a classic that will please...
#
#                                     specific_ingredients  \
# 0      1 tbsp ,butter, 200g ,spinach, 75ml ,double cr...
# 1      1 tbsp ,butter, 200g ,spinach, 75ml ,double cr...
# 2      1 tbsp ,sunflower oil, ½ bunch spring onions,,...
# 3      2 tsp ,olive oil, 400g ,bag fresh spinach, 250...
# 4      85g ,watercress, 50g ,parsley, 50g ,walnut, 15...
# ...                                                  ...
# 10878  500ml ,hot  chicken stock,  or vegetable stock...
# 10879  100g ,dried thin rice noodle, 1 ,red chilli,, ...
# 10880  500g ,beef mince, 2 ,onions,, finely chopped, ...
# 10881  1¼kg ,pork collar, 1 tbsp ,cumin seeds,, fresh...
# 10882  3 tbsp ,lard, 4 ,onions, finely chopped, 1 tbs...
#
#                                              ingredients  preference  \
# 0      butter, spinach, double cream, grated parmesan...     british
# 1      butter, spinach, double cream, grated parmesan...     british
# 2      sunflower oil, ½ bunch spring onions, red pepp...   caribbean
# 3      olive oil, bag fresh spinach, tub ricotta, gra...     italian
# 4        watercress, parsley, walnut, olive oil, sugar,      italian
# ...                                                  ...         ...
# 10878  coconut milk, green or red  Thai curry paste, ...  vietnamese
# 10879  red chilli, carrots, small  red onion, handful...  vietnamese
# 10880  beef mince, onions, garlic cloves, sweet papri...      balkan
# 10881  pork collar, cumin seeds, garlic cloves, onion...       czech
# 10882  onions, cumin seeds, pork shoulder, garlic clo...       czech
#
#                                        final_ingredients
# 0      ['butter', 'spinach', 'cream', 'parmesan', 'nu...
# 1      ['butter', 'spinach', 'cream', 'parmesan', 'nu...
# 2      ['sunflower', 'oil', 'spring', 'onions', 'pepp...
# 3      ['olive', 'oil', 'spinach', 'ricotta', 'nutmeg...
# 4      ['watercress', 'parsley', 'walnut', 'olive', '...
# ...                                                  ...
# 10878  ['coconut', 'milk', 'green', 'thai', 'curry', ...
# 10879  ['chilli', 'carrot', 'onion', 'mint', 'fish', ...
# 10880  ['beef', 'mince', 'onion', 'garlic', 'cloves',...
# 10881  ['pork', 'collar', 'cumin', 'garlic', 'cloves'...
# 10882  ['onion', 'cumin', 'pork', 'shoulder', 'garlic...
#
# [10883 rows x 13 columns]

# %%
def model_specific_preprocessing(tokenized_sentence):
    stop_words = set(stopwords.words('english'))
    no_stopwords = [w for w in tokenized_sentence if not w in stop_words]
    verb_lemmatized = [WordNetLemmatizer().lemmatize(tok, pos = "v") for tok in no_stopwords]
    noun_lemmatized = [WordNetLemmatizer().lemmatize(tok, pos = "n")for tok in verb_lemmatized]
    ingredient_string = ' '.join(noun_lemmatized)
    return ingredient_string

def ingredients_list(sample_txt):
    elements = []
    for punc in string.punctuation:
        sample_txt = sample_txt.replace(punc,'')
    for word in sample_txt.split():
        elements.append(str(word))
    return elements

# %%
def k_means(bbc_final_df, clusters=10, min_df=0.005, max_df=0.99):
    """Returns the df inputted with an additional column with their respective cluster.
    Ensure that the ingredients columns is a string of a list called 'final_ingredients'.
    I.E row 1, col ingredient is '[bread,cheese,pasta,onions]'"""

    # Step 1: Filter out recipes with no names & remove duplicates, keeping dietary info
    filtered_df = bbc_final_df[bbc_final_df['recipe_title']!='n']
    grouped_df = filtered_df.groupby('recipe_title').sum()[['dietary']].reset_index()
    grouped_df.rename(columns = {'dietary':'combined'}, inplace=True)
    merged_df = grouped_df.merge(filtered_df,how='left',on='recipe_title')
    dropped_df = merged_df.drop(columns = 'dietary')
    df = dropped_df.drop_duplicates('recipe_title')

    # Step 2: Convert the final ingredients into a "sentence" for vectorising
    df['ingredients_list'] = df['final_ingredients'].apply(ingredients_list)
    df['clean_text']=df['ingredients_list'].map(lambda x: model_specific_preprocessing(x))

    # Step 3: Convert ingredients sentence into a bag-of-words representation
    vectorizer = CountVectorizer(min_df=min_df, max_df = max_df)
    counted_words = pd.DataFrame(vectorizer.fit_transform(df['clean_text']).toarray(), columns = vectorizer.get_feature_names_out())

    # Step 4: Apply KMeans clustering
    kmeans = KMeans(n_clusters=clusters, random_state=0)
    df['cluster'] = kmeans.fit_predict(counted_words)

    return df

# %%
df1 = k_means(df)
# Out:
# /var/folders/rp/7ftqrxx9701fy2jzfscnlwyw0000gn/T/ipykernel_84717/3738140175.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ingredients_list'] = df['final_ingredients'].apply(ingredients_list)
# /var/folders/rp/7ftqrxx9701fy2jzfscnlwyw0000gn/T/ipykernel_84717/3738140175.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_text']=df['ingredients_list'].map(lambda x: model_specific_preprocessing(x))
# /var/folders/rp/7ftqrxx9701fy2jzfscnlwyw0000gn/T/ipykernel_84717/3738140175.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster'] = kmeans.fit_predict(counted_words)

# %%
df1.tail()

# %%
df1 = df1[df1['preference']=='indian']

# %%
df1 = df1[df1['preference']=='american']

# %%
df1 = df1[df1['stars']!='n'].reset_index(drop=True).sort_values(by='stars', ascending=False).sort_values(by='stars', ascending=False)

# %%
df1 =  df1[df1['combined']=='vegetarian']

# %%
df1 = df1[df1['cluster']==2]

# %%
df1 = df1[df1['preference']!='american']

# %%
df1
# Out:
#                                      recipe_title    combined stars  \
# 1                        10-minute couscous salad  vegetarian   4.7
# 4                 10-minute steak & noodle supper           n   3.0
# 8                  10-minute winter fruit compote           n   4.7
# 12                          15-minute summer soup           n   4.6
# 13                    20-minute Fiorentina pizzas           n   4.7
# ...                                           ...         ...   ...
# 10646                Za'atar & herb potato latkes  vegetarian     n
# 10652  Zesty haddock with crushed potatoes & peas     healthy   4.8
# 10657                      Zesty pomegranate rice  vegetarian   4.0
# 10667                          Zingy radish salad           n     n
# 10669                              Zombie fingers           n   4.0
#
#       prep_times cooking_times review_count difficulty_level  \
# 1             10             n        208.0             Easy
# 4             10             n          3.0             Easy
# 8              5             5          3.0             Easy
# 12            15             n         29.0             Easy
# 13            10            10          6.0             Easy
# ...          ...           ...          ...              ...
# 10646         30            30          1.0             Easy
# 10652         15            20        113.0             Easy
# 10657         10            15          1.0             Easy
# 10667         15             n          2.0             Easy
# 10669         30             n          4.0             Easy
#
#                        servings  \
# 1                      Serves 2
# 4                      Serves 2
# 8                      Serves 4
# 12                     Serves 4
# 13                     Serves 2
# ...                         ...
# 10646  Makes approx. 24 latkes
# 10652                  Serves 4
# 10657                  Serves 4
# 10667                  Serves 4
# 10669           Serves about 15
#
#                                              description  \
# 1      This makes a great lunchbox filler for a day o...
# 4      A super-speedy beef and egg noodle dish – and ...
# 8      Two simple steps make a deliciously fruity pud...
# 12     This soup has a wonderful, fresh peppery flavo...
# 13     Try these cheat's pizzas for a midweek supper....
# ...                                                  ...
# 10646  Latkes are a Jewish classic – essentially, pot...
# 10652  Being pushed for time doesn't mean you have to...
# 10657  This fragrant dish adds an exotic flavour to p...
# 10667  Fiery radishes add crunch to this zesty smoked...
# 10669  These freaky edible fingers are naturally swee...
#
#                                     specific_ingredients  \
# 1      100g ,couscous, 200ml ,hot low salt vegetable ...
# 4      200g ,rump steak, 200g ,pak choi, 1 ,red peppe...
# 8      500g ,pack mixed  dried fruit, 200ml ,fresh or...
# 12     knob of  butter,  or splash of olive oil, bunc...
# 13     250g ,bag spinach, 2 ,large Middle Eastern  fl...
# ...                                                  ...
# 10646  900g ,potatoes, (about 5 large starchy potatoe...
# 10652  600g ,floury potato,, unpeeled, cut into chunk...
# 10657  500ml ,vegetable stock, 250g ,basmati rice, 10...
# 10667  2 ,oranges, 1 tbsp ,red wine vinegar, ½ small ...
# 10669  250g ,stoned dates, 100g ,dark chocolate,, cho...
#
#                                              ingredients      preference  \
# 1      couscous, spring onions, red pepper, feta chee...   mediterranean
# 4                  pak choi, red pepper, sunflower oil,          chinese
# 8      fresh orange juice, half  cinnamon stick, clov...         british
# 12     knob of  butter, bunch spring onions, courgett...         british
# 13     bag spinach, pinch nutmeg, eggs, gruyère, slic...         italian
# ...                                                  ...             ...
# 10646            potatoes, onion, egg, za’atar, tahini,           jewish
# 10652  frozen peas, lemon, capers, haddock, plain flo...         british
# 10657  basmati rice, 100g or 120g tub pomegranate, co...  middle-eastern
# 10667  oranges, ½ small red onion, bag radish, smoked...         british
# 10669  stoned dates, dark chocolate, smooth peanut bu...         british
#
#                                        final_ingredients  \
# 1      ['couscous', 'spring', 'onions', 'pepper', 'fe...
# 4          ['pak', 'choi', 'pepper', 'sunflower', 'oil']
# 8              ['orange', 'cinnamon', 'clove', 'yogurt']
# 12     ['butter', 'spring', 'onions', 'courgette', 'p...
# 13     ['spinach', 'nutmeg', 'egg', 'gruyère', 'prosc...
# ...                                                  ...
# 10646               ['potato', 'onion', 'egg', 'tahini']
# 10652  ['peas', 'lemon', 'caper', 'haddock', 'flour',...
# 10657  ['basmati', 'rice', 'pomegranate', 'coriander'...
# 10667  ['orange', 'onion', 'radish', 'salmon', 'water...
# 10669       ['chocolate', 'peanut', 'butter', 'almonds']
#
#                                         ingredients_list  \
# 1      [couscous, spring, onions, pepper, feta, chees...
# 4                    [pak, choi, pepper, sunflower, oil]
# 8                      [orange, cinnamon, clove, yogurt]
# 12     [butter, spring, onions, courgette, pea, water...
# 13           [spinach, nutmeg, egg, gruyère, prosciutto]
# ...                                                  ...
# 10646                       [potato, onion, egg, tahini]
# 10652     [peas, lemon, caper, haddock, flour, broccoli]
# 10657  [basmati, rice, pomegranate, coriander, cumin,...
# 10667        [orange, onion, radish, salmon, watercress]
# 10669               [chocolate, peanut, butter, almonds]
#
#                                               clean_text  cluster
# 1         couscous spring onion pepper feta cheese pesto        2
# 4                          pak choi pepper sunflower oil        2
# 8                          orange cinnamon cleave yogurt        2
# 12     butter spring onion courgette pea watercress m...        2
# 13                 spinach nutmeg egg gruyère prosciutto        2
# ...                                                  ...      ...
# 10646                            potato onion egg tahini        2
# 10652             pea lemon caper haddock flour broccoli        2
# 10657  basmati rice pomegranate coriander cumin almon...        2
# 10667              orange onion radish salmon watercress        2
# 10669                     chocolate peanut butter almond        2
#
# [1949 rows x 16 columns]

# %%
df1
# Out:
#                                      recipe_title    combined stars  \
# 1                        10-minute couscous salad  vegetarian   4.7
# 4                 10-minute steak & noodle supper           n   3.0
# 8                  10-minute winter fruit compote           n   4.7
# 12                          15-minute summer soup           n   4.6
# 13                    20-minute Fiorentina pizzas           n   4.7
# ...                                           ...         ...   ...
# 10646                Za'atar & herb potato latkes  vegetarian     n
# 10652  Zesty haddock with crushed potatoes & peas     healthy   4.8
# 10657                      Zesty pomegranate rice  vegetarian   4.0
# 10667                          Zingy radish salad           n     n
# 10669                              Zombie fingers           n   4.0
#
#       prep_times cooking_times review_count difficulty_level  \
# 1             10             n        208.0             Easy
# 4             10             n          3.0             Easy
# 8              5             5          3.0             Easy
# 12            15             n         29.0             Easy
# 13            10            10          6.0             Easy
# ...          ...           ...          ...              ...
# 10646         30            30          1.0             Easy
# 10652         15            20        113.0             Easy
# 10657         10            15          1.0             Easy
# 10667         15             n          2.0             Easy
# 10669         30             n          4.0             Easy
#
#                        servings  \
# 1                      Serves 2
# 4                      Serves 2
# 8                      Serves 4
# 12                     Serves 4
# 13                     Serves 2
# ...                         ...
# 10646  Makes approx. 24 latkes
# 10652                  Serves 4
# 10657                  Serves 4
# 10667                  Serves 4
# 10669           Serves about 15
#
#                                              description  \
# 1      This makes a great lunchbox filler for a day o...
# 4      A super-speedy beef and egg noodle dish – and ...
# 8      Two simple steps make a deliciously fruity pud...
# 12     This soup has a wonderful, fresh peppery flavo...
# 13     Try these cheat's pizzas for a midweek supper....
# ...                                                  ...
# 10646  Latkes are a Jewish classic – essentially, pot...
# 10652  Being pushed for time doesn't mean you have to...
# 10657  This fragrant dish adds an exotic flavour to p...
# 10667  Fiery radishes add crunch to this zesty smoked...
# 10669  These freaky edible fingers are naturally swee...
#
#                                     specific_ingredients  \
# 1      100g ,couscous, 200ml ,hot low salt vegetable ...
# 4      200g ,rump steak, 200g ,pak choi, 1 ,red peppe...
# 8      500g ,pack mixed  dried fruit, 200ml ,fresh or...
# 12     knob of  butter,  or splash of olive oil, bunc...
# 13     250g ,bag spinach, 2 ,large Middle Eastern  fl...
# ...                                                  ...
# 10646  900g ,potatoes, (about 5 large starchy potatoe...
# 10652  600g ,floury potato,, unpeeled, cut into chunk...
# 10657  500ml ,vegetable stock, 250g ,basmati rice, 10...
# 10667  2 ,oranges, 1 tbsp ,red wine vinegar, ½ small ...
# 10669  250g ,stoned dates, 100g ,dark chocolate,, cho...
#
#                                              ingredients      preference  \
# 1      couscous, spring onions, red pepper, feta chee...   mediterranean
# 4                  pak choi, red pepper, sunflower oil,          chinese
# 8      fresh orange juice, half  cinnamon stick, clov...         british
# 12     knob of  butter, bunch spring onions, courgett...         british
# 13     bag spinach, pinch nutmeg, eggs, gruyère, slic...         italian
# ...                                                  ...             ...
# 10646            potatoes, onion, egg, za’atar, tahini,           jewish
# 10652  frozen peas, lemon, capers, haddock, plain flo...         british
# 10657  basmati rice, 100g or 120g tub pomegranate, co...  middle-eastern
# 10667  oranges, ½ small red onion, bag radish, smoked...         british
# 10669  stoned dates, dark chocolate, smooth peanut bu...         british
#
#                                        final_ingredients  \
# 1      ['couscous', 'spring', 'onions', 'pepper', 'fe...
# 4          ['pak', 'choi', 'pepper', 'sunflower', 'oil']
# 8              ['orange', 'cinnamon', 'clove', 'yogurt']
# 12     ['butter', 'spring', 'onions', 'courgette', 'p...
# 13     ['spinach', 'nutmeg', 'egg', 'gruyère', 'prosc...
# ...                                                  ...
# 10646               ['potato', 'onion', 'egg', 'tahini']
# 10652  ['peas', 'lemon', 'caper', 'haddock', 'flour',...
# 10657  ['basmati', 'rice', 'pomegranate', 'coriander'...
# 10667  ['orange', 'onion', 'radish', 'salmon', 'water...
# 10669       ['chocolate', 'peanut', 'butter', 'almonds']
#
#                                         ingredients_list  \
# 1      [couscous, spring, onions, pepper, feta, chees...
# 4                    [pak, choi, pepper, sunflower, oil]
# 8                      [orange, cinnamon, clove, yogurt]
# 12     [butter, spring, onions, courgette, pea, water...
# 13           [spinach, nutmeg, egg, gruyère, prosciutto]
# ...                                                  ...
# 10646                       [potato, onion, egg, tahini]
# 10652     [peas, lemon, caper, haddock, flour, broccoli]
# 10657  [basmati, rice, pomegranate, coriander, cumin,...
# 10667        [orange, onion, radish, salmon, watercress]
# 10669               [chocolate, peanut, butter, almonds]
#
#                                               clean_text  cluster
# 1         couscous spring onion pepper feta cheese pesto        2
# 4                          pak choi pepper sunflower oil        2
# 8                          orange cinnamon cleave yogurt        2
# 12     butter spring onion courgette pea watercress m...        2
# 13                 spinach nutmeg egg gruyère prosciutto        2
# ...                                                  ...      ...
# 10646                            potato onion egg tahini        2
# 10652             pea lemon caper haddock flour broccoli        2
# 10657  basmati rice pomegranate coriander cumin almon...        2
# 10667              orange onion radish salmon watercress        2
# 10669                     chocolate peanut butter almond        2
#
# [1949 rows x 16 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
ingredients_cluster = df1[df1['cluster']==2]['clean_text']

# %%
ingredients_cluster
# Out:
# 1           couscous spring onion pepper feta cheese pesto
# 4                            pak choi pepper sunflower oil
# 8                            orange cinnamon cleave yogurt
# 12       butter spring onion courgette pea watercress m...
# 13                   spinach nutmeg egg gruyère prosciutto
#                                ...
# 10646                              potato onion egg tahini
# 10652               pea lemon caper haddock flour broccoli
# 10657    basmati rice pomegranate coriander cumin almon...
# 10667                orange onion radish salmon watercress
# 10669                       chocolate peanut butter almond
# Name: clean_text, Length: 1949, dtype: object

# %%
ingredients_cluster_list = ingredients_cluster.tolist()
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(ingredients_cluster_list)
similarity = cosine_similarity(vectors)

# %%
similar= pd.DataFrame(similarity)

# %%
def ingredients_list(sample_txt):
    elements = []
    for punc in string.punctuation:
        sample_txt = sample_txt.replace(punc,'')
    for word in sample_txt.split():
        elements.append(str(word))
    return elements

def remove_most_common_ings(ing_list):
    too_common = ['oil', 'butter', 'salt', 'clove', 'cloves']
    no_stopwords = [w for w in ing_list if not w in too_common]
    return ' '.join(no_stopwords)

# %%
df['ingredients_list'] = df['final_ingredients'].apply(ingredients_list)
df['temp_nocommon'] = df['ingredients_list'].apply(remove_most_common_ings)
df
# Out:
#                                             recipe_title      dietary stars  \
# 0                                   Easy creamed spinach   vegetarian   4.6
# 1                                   Easy creamed spinach  gluten-free   4.6
# 2                             Simple coconut & bean soup   vegetarian   4.8
# 3                               Free-form Florentine pie   vegetarian   3.8
# 4                                       Fresh herb sauce   vegetarian   4.0
# ...                                                  ...          ...   ...
# 10878                                       Easy noodles            n   3.8
# 10879  Rice noodle & turkey salad with lime-chilli dr...            n   4.3
# 10880                     Cevapcici with red pepper rice            n     n
# 10881                Pork & cabbage with bread dumplings            n     n
# 10882                          Pork & sauerkraut goulash            n     n
#
#       prep_times cooking_times review_count difficulty_level      servings  \
# 0              2             6          5.0             Easy      Serves 2
# 1              2             6          5.0             Easy      Serves 2
# 2             10            20         22.0             Easy      Serves 4
# 3             10            35         14.0             Easy      Serves 4
# 4              5             5          1.0             Easy      Serves 8
# ...          ...           ...          ...              ...           ...
# 10878         20             n         23.0             Easy      Serves 4
# 10879         20            10         10.0             Easy      Serves 4
# 10880         25            30            n             Easy      Serves 4
# 10881         40  3 hrs and 30            n             Easy  Serves 4 - 6
# 10882         10   1 hr and 25            n             Easy  Serves 4 - 6
#
#                                              description  \
# 0      Double cream, Parmesan cheese and a pinch of n...
# 1      Double cream, Parmesan cheese and a pinch of n...
# 2      This vegetarian meal in a bowl shows how somet...
# 3      You're just six ingredients away from an impre...
# 4      This fresh green purée is a light alternative ...
# ...                                                  ...
# 10878  This simple version of a Malaysian classic is ...
# 10879  Lean turkey mince is low in fat - serve with n...
# 10880  These flavourful spiced beef meatballs with to...
# 10881  Try this simple dish of succulent slow-cooked ...
# 10882  Szegedin goulash is a classic that will please...
#
#                                     specific_ingredients  \
# 0      1 tbsp ,butter, 200g ,spinach, 75ml ,double cr...
# 1      1 tbsp ,butter, 200g ,spinach, 75ml ,double cr...
# 2      1 tbsp ,sunflower oil, ½ bunch spring onions,,...
# 3      2 tsp ,olive oil, 400g ,bag fresh spinach, 250...
# 4      85g ,watercress, 50g ,parsley, 50g ,walnut, 15...
# ...                                                  ...
# 10878  500ml ,hot  chicken stock,  or vegetable stock...
# 10879  100g ,dried thin rice noodle, 1 ,red chilli,, ...
# 10880  500g ,beef mince, 2 ,onions,, finely chopped, ...
# 10881  1¼kg ,pork collar, 1 tbsp ,cumin seeds,, fresh...
# 10882  3 tbsp ,lard, 4 ,onions, finely chopped, 1 tbs...
#
#                                              ingredients  preference  \
# 0      butter, spinach, double cream, grated parmesan...     british
# 1      butter, spinach, double cream, grated parmesan...     british
# 2      sunflower oil, ½ bunch spring onions, red pepp...   caribbean
# 3      olive oil, bag fresh spinach, tub ricotta, gra...     italian
# 4        watercress, parsley, walnut, olive oil, sugar,      italian
# ...                                                  ...         ...
# 10878  coconut milk, green or red  Thai curry paste, ...  vietnamese
# 10879  red chilli, carrots, small  red onion, handful...  vietnamese
# 10880  beef mince, onions, garlic cloves, sweet papri...      balkan
# 10881  pork collar, cumin seeds, garlic cloves, onion...       czech
# 10882  onions, cumin seeds, pork shoulder, garlic clo...       czech
#
#                                        final_ingredients  \
# 0      ['butter', 'spinach', 'cream', 'parmesan', 'nu...
# 1      ['butter', 'spinach', 'cream', 'parmesan', 'nu...
# 2      ['sunflower', 'oil', 'spring', 'onions', 'pepp...
# 3      ['olive', 'oil', 'spinach', 'ricotta', 'nutmeg...
# 4      ['watercress', 'parsley', 'walnut', 'olive', '...
# ...                                                  ...
# 10878  ['coconut', 'milk', 'green', 'thai', 'curry', ...
# 10879  ['chilli', 'carrot', 'onion', 'mint', 'fish', ...
# 10880  ['beef', 'mince', 'onion', 'garlic', 'cloves',...
# 10881  ['pork', 'collar', 'cumin', 'garlic', 'cloves'...
# 10882  ['onion', 'cumin', 'pork', 'shoulder', 'garlic...
#
#                                         ingredients_list  \
# 0             [butter, spinach, cream, parmesan, nutmeg]
# 1             [butter, spinach, cream, parmesan, nutmeg]
# 2      [sunflower, oil, spring, onions, pepper, chill...
# 3           [olive, oil, spinach, ricotta, nutmeg, eggs]
# 4       [watercress, parsley, walnut, olive, oil, sugar]
# ...                                                  ...
# 10878  [coconut, milk, green, thai, curry, turmeric, ...
# 10879  [chilli, carrot, onion, mint, fish, sauce, sug...
# 10880  [beef, mince, onion, garlic, cloves, paprika, ...
# 10881  [pork, collar, cumin, garlic, cloves, onion, f...
# 10882  [onion, cumin, pork, shoulder, garlic, cloves,...
#
#                                            temp_nocommon
# 0                          spinach cream parmesan nutmeg
# 1                          spinach cream parmesan nutmeg
# 2      sunflower spring onions pepper chilli garlic t...
# 3                      olive spinach ricotta nutmeg eggs
# 4                  watercress parsley walnut olive sugar
# ...                                                  ...
# 10878  coconut milk green thai curry turmeric chicken...
# 10879  chilli carrot onion mint fish sauce sugar lime...
# 10880  beef mince onion garlic paprika parsley olive ...
# 10881  pork collar cumin garlic onion flour flour egg...
# 10882  onion cumin pork shoulder garlic flour paprika...
#
# [10883 rows x 15 columns]

# %% [markdown]
# # dsfjadsfasd

# %%
ls

# %%
dff = pd.read_csv('bbc_final_df.csv', index_col=0)

# %%
bbc_final_df = dff.copy()
bbc_final_df

# %%
filtered_df = bbc_final_df[bbc_final_df['recipe_title']!='n']
filtered_df

# %%
filtered_df = bbc_final_df[bbc_final_df['recipe_title']!='n']
grouped_df = filtered_df.groupby('recipe_title')['dietary'].apply(lambda x: ', '.join(x)).reset_index().rename(columns = {'dietary':'combined'})
#grouped_df = filtered_df.groupby('recipe_title').sum()[['dietary']].reset_index()
merged_df = grouped_df.merge(filtered_df, how='left',on='recipe_title')
dropped_df = merged_df.drop(columns = 'dietary')
df = dropped_df.drop_duplicates('recipe_title')

# %%
df

# %%
set(df.combined.tolist())

# %%
df.tail(20)

# %%
df['combined'].replace('n','None')

# %%
cuisine_pref = 'american'
diet_pref = 'vegetarian'

# %%
if cuisine_pref and diet_pref == 'Select':
    star_sorted_df = processed_df[processed_df['stars']!='n']
    star_sorted_df = star_sorted_df
    star_sorted_df = star_sorted_df[~star_sorted_df.recipe_title.duplicated()]
    # st.write(star_sorted_df)
    print(star_sorted_df)

if cuisine_pref == 'Select' and diet_pref != 'Select':
    star_sorted_df = processed_df[processed_df['stars']!='n']
    star_sorted_df = star_sorted_df[star_sorted_df['combined'].contains(diet_pref)]
    star_sorted_df = star_sorted_df[~star_sorted_df.recipe_title.duplicated()]
    print(star_sorted_df)

    # st.write(star_sorted_df)
if diet_pref == 'Select'and cuisine_pref != 'Select':
    star_sorted_df = processed_df[processed_df['stars']!='n']
    star_sorted_df = star_sorted_df[star_sorted_df['preference']==cuisine_pref]
    star_sorted_df = star_sorted_df[~star_sorted_df.recipe_title.duplicated()]
    print(star_sorted_df)

# %%
star_sorted_df = processed_df[processed_df['stars']!='n']
star_sorted_df[star_sorted_df['preference']==cuisine_pref]
star_sorted_df = star_sorted_df[~star_sorted_df.recipe_title.duplicated()]
star_sorted_df.reset_index(drop=True,inplace=True)
star_sorted_df.sort_values(by='stars', ascending=False)

# %%
df22 = pd.read_csv('bbc_final_df.csv')

# %%
star_sorted_df = df22.copy()
star_sorted_df=star_sorted_df[star_sorted_df['stars']!='n']

# %%
filtered_df = df22[df22['recipe_title'] != 'n']

grouped_df = filtered_df.groupby('recipe_title')['dietary'].apply(lambda x: ', '.join(x)).reset_index().rename(columns = {'dietary':'combined'})
# grouped_df = filtered_df.groupby('recipe_title').sum()[['dietary']].reset_index()
# grouped_df.rename(columns = {'dietary':'combined'}, inplace=True)
merged_df = grouped_df.merge(filtered_df, how='left',on='recipe_title')
# dropped_df = merged_df.drop(columns = 'dietary')
df = merged_df.drop_duplicates('recipe_title')

# %%
df
